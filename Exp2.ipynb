# %% [markdown]
# # Basic Policy Gradients (REINFORCE) example in PyTorch
#
# Adaptation of lab 6 by Víctor Campos to PyTorch

# %% [markdown]
# ## Installing dependences

# %%
# !apt-get update
# !apt-get install -y python-numpy python-dev cmake zlib1g-dev libjpeg-dev xvfb ffmpeg xorg-dev python-opengl libboost-all-dev libsdl2-dev swig
# !pip install gym pyvirtualdisplay
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [83.2 kB]
# Get:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  InRelease
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1710/x86_64  Release
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64  Release
# Get:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [27.3 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [120 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [1,364 B]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [264 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [574 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [6,953 B]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [736 kB]
# Fetched 1,996 kB in 1s (1,356 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# python-dev is already the newest version (2.7.15~rc1-1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   autotools-dev cmake-data file fontconfig freeglut3 gir1.2-ibus-1.0
#   i965-va-driver ibverbs-providers libaacs0 libarchive13 libasound2
#   libasound2-data libasound2-dev libass9 libasyncns0 libavc1394-0 libavcodec57
#   libavdevice57 libavfilter6 libavformat57 libavresample3 libavutil55
#   libbdplus0 libbluray2 libboost-atomic-dev libboost-atomic1.65-dev
#   libboost-atomic1.65.1 libboost-chrono-dev libboost-chrono1.65-dev
#   libboost-chrono1.65.1 libboost-container-dev libboost-container1.65-dev
#   libboost-container1.65.1 libboost-context-dev libboost-context1.65-dev
#   libboost-context1.65.1 libboost-coroutine-dev libboost-coroutine1.65-dev
#   libboost-coroutine1.65.1 libboost-date-time-dev libboost-date-time1.65-dev
#   libboost-date-time1.65.1 libboost-dev libboost-exception-dev
#   libboost-exception1.65-dev libboost-fiber-dev libboost-fiber1.65-dev
#   libboost-fiber1.65.1 libboost-filesystem-dev libboost-filesystem1.65-dev
#   libboost-filesystem1.65.1 libboost-graph-dev libboost-graph-parallel-dev
#   libboost-graph-parallel1.65-dev libboost-graph-parallel1.65.1
#   libboost-graph1.65-dev libboost-graph1.65.1 libboost-iostreams-dev
#   libboost-iostreams1.65-dev libboost-iostreams1.65.1 libboost-locale-dev
#   libboost-locale1.65-dev libboost-locale1.65.1 libboost-log-dev
#   libboost-log1.65-dev libboost-log1.65.1 libboost-math-dev
#   libboost-math1.65-dev libboost-math1.65.1 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.65-dev
#   libboost-mpi-python1.65.1 libboost-mpi1.65-dev libboost-mpi1.65.1
#   libboost-numpy-dev libboost-numpy1.65-dev libboost-numpy1.65.1
#   libboost-program-options-dev libboost-program-options1.65-dev
#   libboost-program-options1.65.1 libboost-python-dev libboost-python1.65-dev
#   libboost-python1.65.1 libboost-random-dev libboost-random1.65-dev
#   libboost-random1.65.1 libboost-regex-dev libboost-regex1.65-dev
#   libboost-regex1.65.1 libboost-serialization-dev
#   libboost-serialization1.65-dev libboost-serialization1.65.1
#   libboost-signals-dev libboost-signals1.65-dev libboost-signals1.65.1
#   libboost-stacktrace-dev libboost-stacktrace1.65-dev
#   libboost-stacktrace1.65.1 libboost-system-dev libboost-system1.65-dev
#   libboost-system1.65.1 libboost-test-dev libboost-test1.65-dev
#   libboost-test1.65.1 libboost-thread-dev libboost-thread1.65-dev
#   libboost-thread1.65.1 libboost-timer-dev libboost-timer1.65-dev
#   libboost-timer1.65.1 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.65-dev libboost-type-erasure1.65.1 libboost-wave-dev
#   libboost-wave1.65-dev libboost-wave1.65.1 libboost1.65-dev
#   libboost1.65-tools-dev libbs2b0 libcaca0 libcairo2 libcapnp-0.6.1
#   libcdio-cdda2 libcdio-paranoia2 libcdio17 libchromaprint1 libcroco3
#   libcrystalhd3 libdatrie1 libdbus-1-dev libdc1394-22 libdmx-dev libdmx1
#   libdrm-amdgpu1 libdrm-dev libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libegl1-mesa-dev libfabric1 libfftw3-double3 libflac8 libflite1
#   libfontenc-dev libfontenc1 libfribidi0 libfs-dev libfs6 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dev
#   libgl1-mesa-dri libgles1 libgles2-mesa-dev libglu1-mesa libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-mesa0 libglx0 libgme0 libgsm1
#   libhwloc-dev libhwloc-plugins libhwloc5 libibus-1.0-5 libibus-1.0-dev
#   libibverbs-dev libibverbs1 libice-dev libiec61883-0 libjack-jackd2-0
#   libjbig0 libjsoncpp1 libllvm6.0 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc
#   libmagic1 libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libmp3lame0 libmpg123-0 libmysofa0 libnl-3-200 libnl-route-3-200 libnuma-dev
#   libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpi-dev
#   libopenmpi2 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess-dev libpciaccess0 libpixman-1-0
#   libpixman-1-dev libpostproc54 libprotobuf-dev libprotobuf-lite10
#   libprotobuf10 libpsm-infinipath1 libpulse-dev libpulse-mainloop-glib0
#   libpulse0 libraw1394-11 librdmacm1 librhash0 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors4 libshine3 libslang2
#   libsm-dev libsnappy1v5 libsndfile1 libsndio-dev libsndio6.1 libsoxr0
#   libspeex1 libssh-gcrypt-4 libswresample2 libswscale4 libthai-data libthai0
#   libtheora0 libtiff5 libtool libtwolame0 libudev-dev libudev1 libusb-1.0-0
#   libuv1 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx5 libwavpack1 libwayland-bin libwayland-cursor0
#   libwayland-dev libwayland-egl1-mesa libwebp6 libwebpmux3 libwrap0
#   libx11-xcb-dev libx264-152 libx265-146 libxaw7 libxaw7-dev libxcb-dri2-0-dev
#   libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev libxcb-present-dev libxcb-randr0
#   libxcb-randr0-dev libxcb-render0 libxcb-render0-dev libxcb-shape0
#   libxcb-shape0-dev libxcb-shm0 libxcb-sync-dev libxcb-xfixes0-dev
#   libxcomposite-dev libxcomposite1 libxcursor-dev libxcursor1 libxdamage-dev
#   libxdamage1 libxext-dev libxfixes-dev libxfixes3 libxfont-dev libxfont2
#   libxi-dev libxi6 libxinerama-dev libxinerama1 libxkbcommon-dev libxkbcommon0
#   libxkbfile-dev libxkbfile1 libxmu-dev libxmu-headers libxmu6 libxmuu-dev
#   libxmuu1 libxpm-dev libxpm4 libxrandr-dev libxrandr2 libxres-dev libxres1
#   libxshmfence-dev libxss-dev libxt-dev libxt6 libxtst-dev libxtst6 libxv-dev
#   libxv1 libxvidcore4 libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1
#   libxxf86vm-dev libxxf86vm1 libzvbi-common libzvbi0 mesa-common-dev
#   mesa-va-drivers mesa-vdpau-drivers mir-client-platform-mesa-dev
#   mpi-default-bin mpi-default-dev ocl-icd-libopencl1 openmpi-bin
#   openmpi-common shared-mime-info swig3.0 va-driver-all vdpau-driver-all
#   x11-xkb-utils x11proto-composite-dev x11proto-damage-dev x11proto-dri2-dev
#   x11proto-fixes-dev x11proto-fonts-dev x11proto-gl-dev x11proto-input-dev
#   x11proto-randr-dev x11proto-record-dev x11proto-render-dev
#   x11proto-resource-dev x11proto-scrnsaver-dev x11proto-xext-dev
#   x11proto-xf86bigfont-dev x11proto-xf86dga-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev xauth xfonts-base xfonts-encodings xfonts-utils
#   xkb-data xserver-common xserver-xorg-dev
# Suggested packages:
#   cmake-doc ninja-build ffmpeg-doc i965-va-driver-shaders lrzip
#   libasound2-plugins alsa-utils libasound2-doc libbluray-bdj libboost-doc
#   graphviz libboost1.65-doc gccxml libmpfrc++-dev libntl-dev xsltproc doxygen
#   docbook-xml docbook-xsl default-jdk fop firmware-crystalhd libfftw3-bin
#   libfftw3-dev libhwloc-contrib-plugins libice-doc jackd2 libtool-doc
#   libportaudio2 openmpi-doc opus-tools pciutils pulseaudio libraw1394-doc
#   librsvg2-bin lm-sensors libsm-doc sndiod speex autoconf automaken gcj-jdk
#   libxaw-doc libxext-doc libxt-doc python-nose python-numpy-dbg
#   python-numpy-doc libgle3 swig-doc swig-examples swig3.0-examples swig3.0-doc
#   libvdpau-va-gl1 nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
# The following NEW packages will be installed:
#   autotools-dev cmake cmake-data ffmpeg file fontconfig freeglut3
#   gir1.2-ibus-1.0 i965-va-driver ibverbs-providers libaacs0 libarchive13
#   libasound2 libasound2-data libasound2-dev libass9 libasyncns0 libavc1394-0
#   libavcodec57 libavdevice57 libavfilter6 libavformat57 libavresample3
#   libavutil55 libbdplus0 libbluray2 libboost-all-dev libboost-atomic-dev
#   libboost-atomic1.65-dev libboost-atomic1.65.1 libboost-chrono-dev
#   libboost-chrono1.65-dev libboost-chrono1.65.1 libboost-container-dev
#   libboost-container1.65-dev libboost-container1.65.1 libboost-context-dev
#   libboost-context1.65-dev libboost-context1.65.1 libboost-coroutine-dev
#   libboost-coroutine1.65-dev libboost-coroutine1.65.1 libboost-date-time-dev
#   libboost-date-time1.65-dev libboost-date-time1.65.1 libboost-dev
#   libboost-exception-dev libboost-exception1.65-dev libboost-fiber-dev
#   libboost-fiber1.65-dev libboost-fiber1.65.1 libboost-filesystem-dev
#   libboost-filesystem1.65-dev libboost-filesystem1.65.1 libboost-graph-dev
#   libboost-graph-parallel-dev libboost-graph-parallel1.65-dev
#   libboost-graph-parallel1.65.1 libboost-graph1.65-dev libboost-graph1.65.1
#   libboost-iostreams-dev libboost-iostreams1.65-dev libboost-iostreams1.65.1
#   libboost-locale-dev libboost-locale1.65-dev libboost-locale1.65.1
#   libboost-log-dev libboost-log1.65-dev libboost-log1.65.1 libboost-math-dev
#   libboost-math1.65-dev libboost-math1.65.1 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.65-dev
#   libboost-mpi-python1.65.1 libboost-mpi1.65-dev libboost-mpi1.65.1
#   libboost-numpy-dev libboost-numpy1.65-dev libboost-numpy1.65.1
#   libboost-program-options-dev libboost-program-options1.65-dev
#   libboost-program-options1.65.1 libboost-python-dev libboost-python1.65-dev
#   libboost-python1.65.1 libboost-random-dev libboost-random1.65-dev
#   libboost-random1.65.1 libboost-regex-dev libboost-regex1.65-dev
#   libboost-regex1.65.1 libboost-serialization-dev
#   libboost-serialization1.65-dev libboost-serialization1.65.1
#   libboost-signals-dev libboost-signals1.65-dev libboost-signals1.65.1
#   libboost-stacktrace-dev libboost-stacktrace1.65-dev
#   libboost-stacktrace1.65.1 libboost-system-dev libboost-system1.65-dev
#   libboost-system1.65.1 libboost-test-dev libboost-test1.65-dev
#   libboost-test1.65.1 libboost-thread-dev libboost-thread1.65-dev
#   libboost-thread1.65.1 libboost-timer-dev libboost-timer1.65-dev
#   libboost-timer1.65.1 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.65-dev libboost-type-erasure1.65.1 libboost-wave-dev
#   libboost-wave1.65-dev libboost-wave1.65.1 libboost1.65-dev
#   libboost1.65-tools-dev libbs2b0 libcaca0 libcairo2 libcapnp-0.6.1
#   libcdio-cdda2 libcdio-paranoia2 libcdio17 libchromaprint1 libcroco3
#   libcrystalhd3 libdatrie1 libdbus-1-dev libdc1394-22 libdmx-dev libdmx1
#   libdrm-amdgpu1 libdrm-dev libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libegl1-mesa-dev libfabric1 libfftw3-double3 libflac8 libflite1
#   libfontenc-dev libfontenc1 libfribidi0 libfs-dev libfs6 libgdk-pixbuf2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1 libgl1-mesa-dev
#   libgl1-mesa-dri libgles1 libgles2-mesa-dev libglu1-mesa libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libglx-mesa0 libglx0 libgme0 libgsm1
#   libhwloc-dev libhwloc-plugins libhwloc5 libibus-1.0-5 libibus-1.0-dev
#   libibverbs-dev libibverbs1 libice-dev libiec61883-0 libjack-jackd2-0
#   libjbig0 libjsoncpp1 libllvm6.0 libltdl-dev libltdl7 liblzo2-2 libmagic-mgc
#   libmagic1 libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libmp3lame0 libmpg123-0 libmysofa0 libnl-3-200 libnl-route-3-200 libnuma-dev
#   libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpi-dev
#   libopenmpi2 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess-dev libpciaccess0 libpixman-1-0
#   libpixman-1-dev libpostproc54 libprotobuf-dev libprotobuf-lite10
#   libprotobuf10 libpsm-infinipath1 libpulse-dev libpulse-mainloop-glib0
#   libpulse0 libraw1394-11 librdmacm1 librhash0 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsdl2-dev libsensors4
#   libshine3 libslang2 libsm-dev libsnappy1v5 libsndfile1 libsndio-dev
#   libsndio6.1 libsoxr0 libspeex1 libssh-gcrypt-4 libswresample2 libswscale4
#   libthai-data libthai0 libtheora0 libtiff5 libtool libtwolame0 libudev-dev
#   libusb-1.0-0 libuv1 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libwavpack1 libwayland-bin
#   libwayland-cursor0 libwayland-dev libwayland-egl1-mesa libwebp6 libwebpmux3
#   libwrap0 libx11-xcb-dev libx264-152 libx265-146 libxaw7 libxaw7-dev
#   libxcb-dri2-0-dev libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev
#   libxcb-present-dev libxcb-randr0 libxcb-randr0-dev libxcb-render0
#   libxcb-render0-dev libxcb-shape0 libxcb-shape0-dev libxcb-shm0
#   libxcb-sync-dev libxcb-xfixes0-dev libxcomposite-dev libxcomposite1
#   libxcursor-dev libxcursor1 libxdamage-dev libxdamage1 libxext-dev
#   libxfixes-dev libxfixes3 libxfont-dev libxfont2 libxi-dev libxi6
#   libxinerama-dev libxinerama1 libxkbcommon-dev libxkbcommon0 libxkbfile-dev
#   libxkbfile1 libxmu-dev libxmu-headers libxmu6 libxmuu-dev libxmuu1
#   libxpm-dev libxpm4 libxrandr-dev libxrandr2 libxres-dev libxres1
#   libxshmfence-dev libxss-dev libxt-dev libxt6 libxtst-dev libxtst6 libxv-dev
#   libxv1 libxvidcore4 libxvmc-dev libxvmc1 libxxf86dga-dev libxxf86dga1
#   libxxf86vm-dev libxxf86vm1 libzvbi-common libzvbi0 mesa-common-dev
#   mesa-va-drivers mesa-vdpau-drivers mir-client-platform-mesa-dev
#   mpi-default-bin mpi-default-dev ocl-icd-libopencl1 openmpi-bin
#   openmpi-common python-numpy python-opengl shared-mime-info swig swig3.0
#   va-driver-all vdpau-driver-all x11-xkb-utils x11proto-composite-dev
#   x11proto-damage-dev x11proto-dri2-dev x11proto-fixes-dev x11proto-fonts-dev
#   x11proto-gl-dev x11proto-input-dev x11proto-randr-dev x11proto-record-dev
#   x11proto-render-dev x11proto-resource-dev x11proto-scrnsaver-dev
#   x11proto-xext-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xf86vidmode-dev x11proto-xinerama-dev xauth xfonts-base
#   xfonts-encodings xfonts-utils xkb-data xorg-dev xserver-common
#   xserver-xorg-dev xvfb
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 382 newly installed, 0 to remove and 8 not upgraded.
# Need to get 106 MB of archives.
# After this operation, 674 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fontconfig amd64 2.12.6-0ubuntu2 [169 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdmx1 amd64 1:1.1.3-1 [10.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama1 amd64 2:1.1.3-1 [7,908 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev1 amd64 237-3ubuntu10.9 [53.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.1 [184 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.1 [68.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.1 [22.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfribidi0 amd64 0.19.7-2 [24.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libslang2 amd64 2.3.1a-3ubuntu1 [424 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 shared-mime-info amd64 1.9-2 [426 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 xkb-data all 2.23.1-1ubuntu1 [325 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnuma1 amd64 2.0.11-2.1 [21.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmuu1 amd64 2:1.1.2-2 [9,674 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 xauth amd64 1:1.0.10-1 [24.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 cmake-data all 3.10.2-1ubuntu2 [1,331 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive13 amd64 3.2.2-3.1ubuntu0.1 [289 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjsoncpp1 amd64 1.7.4-3 [73.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 librhash0 amd64 1.3.6-2 [78.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libuv1 amd64 1.18.0-3 [64.4 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 cmake amd64 3.10.2-1ubuntu2 [3,138 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva2 amd64 2.1.0-3 [47.6 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-drm2 amd64 2.1.0-3 [6,880 B]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-x11-2 amd64 2.1.0-3 [11.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvdpau1 amd64 1.1.1-3ubuntu1 [25.5 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavutil55 amd64 7:3.4.4-0ubuntu0.18.04.1 [190 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-0 amd64 0.34.0-2 [229 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-render0 amd64 1.13-1 [14.7 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shm0 amd64 1.13-1 [5,572 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcairo2 amd64 1.15.10-2 [580 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-12 [45.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsm1 amd64 1.0.13-4build1 [22.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmp3lame0 amd64 3.100-2 [136 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenjp2-7 amd64 2.3.0-1 [145 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libopus0 amd64 1.1.2-1ubuntu1 [159 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcroco3 amd64 0.6.12-2 [81.3 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig0 amd64 2.1-3.1build1 [26.7 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtiff5 amd64 4.0.9-5 [152 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-common all 2.36.11-2 [4,536 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-2 [165 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai-data all 0.1.27-2 [133 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdatrie1 amd64 0.2.10-7 [17.8 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libthai0 amd64 0.1.27-2 [18.0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango-1.0-0 amd64 1.40.14-1ubuntu0.1 [153 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoft2-1.0-0 amd64 1.40.14-1ubuntu0.1 [33.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangocairo-1.0-0 amd64 1.40.14-1ubuntu0.1 [20.8 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 librsvg2-2 amd64 2.40.20-2 [98.6 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libshine3 amd64 3.1.1-1 [22.9 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy1v5 amd64 1.1.7-1 [16.0 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu2 [52.1 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswresample2 amd64 7:3.4.4-0ubuntu0.18.04.1 [55.2 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtwolame0 amd64 0.3.13-3 [46.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbis0a amd64 1.3.5-4.2 [86.4 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisenc2 amd64 1.3.5-4.2 [70.7 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvpx5 amd64 1.7.0-3 [798 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu1.1 [76.6 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebp6 amd64 0.6.1-2 [185 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwebpmux3 amd64 0.6.1-2 [19.6 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx264-152 amd64 2:0.152.2854+gite9a5903-2 [609 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx265-146 amd64 2.6-3 [1,026 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxvidcore4 amd64 2:1.3.5-1 [200 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi-common all 0.2.35-13 [32.1 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi0 amd64 0.2.35-13 [235 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavcodec57 amd64 7:3.4.4-0ubuntu0.18.04.1 [4,592 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2-data all 1.1.3-5ubuntu0.1 [36.3 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2 amd64 1.1.3-5ubuntu0.1 [359 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/main amd64 libavc1394-0 amd64 0.5.4-4build1 [16.1 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libass9 amd64 1:0.14.0-1 [88.2 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbluray2 amd64 1:1.0.2-3 [141 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libchromaprint1 amd64 1.4.3-1 [36.8 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpg123-0 amd64 1.25.10-1 [125 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisfile3 amd64 1.3.5-4.2 [16.0 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpt0 amd64 0.3.6-1 [561 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssh-gcrypt-4 amd64 0.8.0~20170825.94fa1e38-1ubuntu0.1 [171 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavformat57 amd64 7:3.4.4-0ubuntu0.18.04.1 [949 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavresample3 amd64 7:3.4.4-0ubuntu0.18.04.1 [52.6 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2 [10.5 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libflite1 amd64 2.1-release-1 [12.8 MB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmysofa0 amd64 0.6~dfsg0-2 [37.8 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libpostproc54 amd64 7:3.4.4-0ubuntu0.18.04.1 [50.4 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfftw3-double3 amd64 3.3.7-1 [735 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsamplerate0 amd64 0.1.9-1 [938 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic/universe amd64 librubberband2 amd64 1.8.1-7ubuntu2 [86.7 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswscale4 amd64 7:3.4.4-0ubuntu0.18.04.1 [150 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavfilter6 amd64 7:3.4.4-0ubuntu0.18.04.1 [874 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcaca0 amd64 0.99.beta19-2build2~gcc5.3 [202 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio17 amd64 1.0.0-2ubuntu2 [58.8 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-cdda2 amd64 10.2+0.94+2-2build1 [17.7 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdio-paranoia2 amd64 10.2+0.94+2-2build1 [17.2 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdc1394-22 amd64 2.2.5-1 [77.5 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-glx0 amd64 1.13-1 [22.0 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage1 amd64 1:1.1.4-3 [6,934 B]
# Get:103 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-amdgpu1 amd64 2.4.91-2 [19.0 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpciaccess0 amd64 0.14-1 [17.9 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-intel1 amd64 2.4.91-2 [59.8 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-nouveau2 amd64 2.4.91-2 [16.5 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-radeon1 amd64 2.4.91-2 [21.7 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/main amd64 libllvm6.0 amd64 1:6.0-1ubuntu2 [14.5 MB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsensors4 amd64 1:3.4.0-4 [28.8 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dri amd64 18.0.5-0ubuntu0~18.04.1 [6,011 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx-mesa0 amd64 18.0.5-0ubuntu0~18.04.1 [132 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx0 amd64 1.0.0-2ubuntu2.2 [28.1 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1 amd64 1.0.0-2ubuntu2.2 [84.8 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic/main amd64 libiec61883-0 amd64 1.2.0-2 [23.5 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjack-jackd2-0 amd64 1.9.12~dfsg-2 [263 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-data all 1:1.18.2-2 [102 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio6.1 amd64 1.1.0-3 [23.4 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal1 amd64 1:1.18.2-2 [266 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/main amd64 libasyncns0 amd64 0.8-6 [12.1 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/main amd64 libflac8 amd64 1.3.2-1 [213 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsndfile1 amd64 1.0.28-4 [169 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwrap0 amd64 7.6.q-27 [46.3 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse0 amd64 1:11.1-1ubuntu7.1 [265 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwayland-cursor0 amd64 1.14.0-2 [9,976 B]
# Get:125 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-egl1-mesa amd64 18.0.5-0ubuntu0~18.04.1 [7,148 B]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor1 amd64 1:1.1.15-1 [19.8 kB]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon0 amd64 0.8.0-1ubuntu0.1 [97.9 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-2.0-0 amd64 2.0.8+dfsg1-1ubuntu1.18.04.1 [378 kB]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shape0 amd64 1.13-1 [5,964 B]
# Get:132 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv1 amd64 2:1.0.11-1 [10.7 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavdevice57 amd64 7:3.4.4-0ubuntu0.18.04.1 [74.9 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 ffmpeg amd64 7:3.4.4-0ubuntu0.18.04.1 [1,587 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu4 [134 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu4 [66.6 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-3-200 amd64 3.2.29-0ubuntu3 [52.8 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-route-3-200 amd64 3.2.29-0ubuntu3 [146 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibverbs1 amd64 17.1-1 [44.4 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic/main amd64 ibverbs-providers amd64 17.1-1 [160 kB]
# Get:142 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libaacs0 amd64 0.9.0-1 [51.4 kB]
# Get:143 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libasound2-dev amd64 1.1.3-5ubuntu0.1 [123 kB]
# Get:144 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbdplus0 amd64 0.1.2-2 [46.6 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [7,218 kB]
# Get:146 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-dev amd64 1.65.1.0ubuntu1 [3,128 B]
# Get:147 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost1.65-tools-dev amd64 1.65.1+dfsg-0ubuntu5 [1,222 kB]
# Get:148 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-tools-dev amd64 1.65.1.0ubuntu1 [3,096 B]
# Get:149 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-atomic1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [7,268 B]
# Get:150 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-atomic1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [5,160 B]
# Get:151 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-atomic-dev amd64 1.65.1.0ubuntu1 [3,224 B]
# Get:152 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-system1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [10.5 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-chrono1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [10.2 kB]
# Get:154 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-chrono1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [9,804 B]
# Get:155 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-chrono-dev amd64 1.65.1.0ubuntu1 [3,544 B]
# Get:156 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-container1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [43.4 kB]
# Get:157 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-container1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [41.7 kB]
# Get:158 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-container-dev amd64 1.65.1.0ubuntu1 [3,400 B]
# Get:159 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-context1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [8,336 B]
# Get:160 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-context1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [6,364 B]
# Get:161 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-context-dev amd64 1.65.1.0ubuntu1 [3,120 B]
# Get:162 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-thread1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [43.2 kB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-coroutine1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [22.6 kB]
# Get:164 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-coroutine1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [24.2 kB]
# Get:165 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-coroutine-dev amd64 1.65.1.0ubuntu1 [3,196 B]
# Get:166 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-date-time1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [20.5 kB]
# Get:167 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-serialization1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [99.3 kB]
# Get:168 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-serialization1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [137 kB]
# Get:169 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-date-time1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [26.7 kB]
# Get:170 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-date-time-dev amd64 1.65.1.0ubuntu1 [2,924 B]
# Get:171 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-exception1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [4,580 B]
# Get:172 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-exception-dev amd64 1.65.1.0ubuntu1 [2,916 B]
# Get:173 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-filesystem1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [40.3 kB]
# Get:174 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-fiber1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [108 kB]
# Get:175 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-fiber1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [121 kB]
# Get:176 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-fiber-dev amd64 1.65.1.0ubuntu1 [3,348 B]
# Get:177 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-system1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [11.8 kB]
# Get:178 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-filesystem1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [52.1 kB]
# Get:179 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-filesystem-dev amd64 1.65.1.0ubuntu1 [2,960 B]
# Get:180 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-regex1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [259 kB]
# Get:181 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [93.4 kB]
# Get:182 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-test1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [240 kB]
# Get:183 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-test1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [289 kB]
# Get:184 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [102 kB]
# Get:185 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-dev amd64 1.65.1.0ubuntu1 [3,024 B]
# Get:186 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpsm-infinipath1 amd64 3.3+20.604758e7-5 [174 kB]
# Get:187 http://archive.ubuntu.com/ubuntu bionic/main amd64 librdmacm1 amd64 17.1-1 [56.1 kB]
# Get:188 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfabric1 amd64 1.5.3-1 [302 kB]
# Get:189 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:190 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc5 amd64 1.11.9-1 [105 kB]
# Get:191 http://archive.ubuntu.com/ubuntu bionic/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:192 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc-plugins amd64 1.11.9-1 [12.5 kB]
# Get:193 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpi2 amd64 2.1.1-8 [2,056 kB]
# Get:194 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [47.0 kB]
# Get:195 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-parallel1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [62.3 kB]
# Get:196 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-parallel1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [64.5 kB]
# Get:197 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-graph-parallel-dev amd64 1.65.1.0ubuntu1 [3,056 B]
# Get:198 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-regex1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [312 kB]
# Get:199 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-iostreams1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [29.2 kB]
# Get:200 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-iostreams1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [37.0 kB]
# Get:201 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-iostreams-dev amd64 1.65.1.0ubuntu1 [2,916 B]
# Get:202 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-locale1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [241 kB]
# Get:203 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-locale1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [329 kB]
# Get:204 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-locale-dev amd64 1.65.1.0ubuntu1 [3,248 B]
# Get:205 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-log1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [384 kB]
# Get:206 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-thread1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [49.0 kB]
# Get:207 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-log1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [553 kB]
# Get:208 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-log-dev amd64 1.65.1.0ubuntu1 [3,124 B]
# Get:209 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-math1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [311 kB]
# Get:210 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-math1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [560 kB]
# Get:211 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-math-dev amd64 1.65.1.0ubuntu1 [3,112 B]
# Get:212 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openmpi-common all 2.1.1-8 [140 kB]
# Get:213 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibverbs-dev amd64 17.1-1 [103 kB]
# Get:214 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnuma-dev amd64 2.0.11-2.1 [32.2 kB]
# Get:215 http://archive.ubuntu.com/ubuntu bionic/main amd64 libltdl-dev amd64 2.4.6-2 [162 kB]
# Get:216 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc-dev amd64 1.11.9-1 [167 kB]
# Get:217 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpi-dev amd64 2.1.1-8 [925 kB]
# Get:218 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mpi-default-dev amd64 1.10 [3,888 B]
# Get:219 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [137 kB]
# Get:220 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-dev amd64 1.65.1.0ubuntu1 [3,004 B]
# Get:221 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-python1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [101 kB]
# Get:222 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openmpi-bin amd64 2.1.1-8 [88.2 kB]
# Get:223 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mpi-default-bin amd64 1.10 [3,108 B]
# Get:224 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-python1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [214 kB]
# Get:225 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-python1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [24.7 kB]
# Get:226 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-mpi-python-dev amd64 1.65.1.0ubuntu1 [3,040 B]
# Get:227 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-numpy1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [17.4 kB]
# Get:228 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-numpy1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [17.4 kB]
# Get:229 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-numpy-dev amd64 1.65.1.0ubuntu1 [2,960 B]
# Get:230 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-program-options1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [137 kB]
# Get:231 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-program-options1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [163 kB]
# Get:232 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-program-options-dev amd64 1.65.1.0ubuntu1 [2,940 B]
# Get:233 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-python1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [103 kB]
# Get:234 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-python-dev amd64 1.65.1.0ubuntu1 [3,216 B]
# Get:235 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-random1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [12.8 kB]
# Get:236 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-random1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [12.4 kB]
# Get:237 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-random-dev amd64 1.65.1.0ubuntu1 [2,924 B]
# Get:238 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-regex-dev amd64 1.65.1.0ubuntu1 [3,184 B]
# Get:239 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-serialization-dev amd64 1.65.1.0ubuntu1 [3,144 B]
# Get:240 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-signals1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [30.6 kB]
# Get:241 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-signals1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [33.1 kB]
# Get:242 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-signals-dev amd64 1.65.1.0ubuntu1 [2,996 B]
# Get:243 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-stacktrace1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [49.1 kB]
# Get:244 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-stacktrace1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [25.9 kB]
# Get:245 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-stacktrace-dev amd64 1.65.1.0ubuntu1 [2,924 B]
# Get:246 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-system-dev amd64 1.65.1.0ubuntu1 [3,060 B]
# Get:247 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-test-dev amd64 1.65.1.0ubuntu1 [2,960 B]
# Get:248 http://archive.ubuntu.com/ubuntu bionic/main amd64 libboost-thread-dev amd64 1.65.1.0ubuntu1 [2,948 B]
# Get:249 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-timer1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [11.9 kB]
# Get:250 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-timer1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [11.8 kB]
# Get:251 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-timer-dev amd64 1.65.1.0ubuntu1 [3,044 B]
# Get:252 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-type-erasure1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [20.7 kB]
# Get:253 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-type-erasure1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [20.1 kB]
# Get:254 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-type-erasure-dev amd64 1.65.1.0ubuntu1 [3,024 B]
# Get:255 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-wave1.65.1 amd64 1.65.1+dfsg-0ubuntu5 [178 kB]
# Get:256 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-wave1.65-dev amd64 1.65.1+dfsg-0ubuntu5 [234 kB]
# Get:257 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-wave-dev amd64 1.65.1.0ubuntu1 [2,952 B]
# Get:258 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libboost-all-dev amd64 1.65.1.0ubuntu1 [2,340 B]
# Get:259 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:260 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1 [165 kB]
# Get:261 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdmx-dev amd64 1:1.1.3-1 [34.4 kB]
# Get:262 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdrm-dev amd64 2.4.91-2 [238 kB]
# Get:263 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd-core-dev amd64 1.0.0-2ubuntu2.2 [12.9 kB]
# Get:264 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles1 amd64 1.0.0-2ubuntu2.2 [11.2 kB]
# Get:265 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd-dev amd64 1.0.0-2ubuntu2.2 [3,408 B]
# Get:266 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-dri2-dev all 2018.4-4 [2,620 B]
# Get:267 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-gl-dev all 2018.4-4 [2,612 B]
# Get:268 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xext-dev all 2018.4-4 [2,620 B]
# Get:269 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxext-dev amd64 2:1.3.3-1 [82.1 kB]
# Get:270 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xf86vidmode-dev all 2018.4-4 [2,632 B]
# Get:271 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86vm-dev amd64 1:1.1.4-1 [13.3 kB]
# Get:272 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fixes-dev all 1:2018.4-4 [2,620 B]
# Get:273 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes-dev amd64 1:5.0.3-1 [11.0 kB]
# Get:274 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-damage-dev all 1:2018.4-4 [2,620 B]
# Get:275 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage-dev amd64 1:1.1.4-3 [5,028 B]
# Get:276 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-glx0-dev amd64 1.13-1 [27.9 kB]
# Get:277 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-dri2-0-dev amd64 1.13-1 [8,476 B]
# Get:278 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-dri3-dev amd64 1.13-1 [7,368 B]
# Get:279 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-randr0 amd64 1.13-1 [16.4 kB]
# Get:280 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-render0-dev amd64 1.13-1 [18.4 kB]
# Get:281 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-randr0-dev amd64 1.13-1 [20.4 kB]
# Get:282 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-shape0-dev amd64 1.13-1 [7,144 B]
# Get:283 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-xfixes0-dev amd64 1.13-1 [11.7 kB]
# Get:284 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-sync-dev amd64 1.13-1 [10.6 kB]
# Get:285 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcb-present-dev amd64 1.13-1 [6,968 B]
# Get:286 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxshmfence-dev amd64 1.3-1 [3,692 B]
# Get:287 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-xcb-dev amd64 2:1.6.4-3ubuntu0.1 [9,764 B]
# Get:288 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwayland-bin amd64 1.14.0-2 [19.0 kB]
# Get:289 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwayland-dev amd64 1.14.0-2 [98.2 kB]
# Get:290 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl1-mesa-dev amd64 18.0.5-0ubuntu0~18.04.1 [19.8 kB]
# Get:291 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc1 amd64 1:1.1.3-1 [13.9 kB]
# Get:292 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc-dev amd64 1:1.1.3-1 [13.8 kB]
# Get:293 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfs6 amd64 2:1.0.7-1 [22.5 kB]
# Get:294 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fonts-dev all 2018.4-4 [2,620 B]
# Get:295 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfs-dev amd64 2:1.0.7-1 [26.8 kB]
# Get:296 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-bin amd64 2.36.11-2 [7,864 B]
# Get:297 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles2-mesa-dev amd64 18.0.5-0ubuntu0~18.04.1 [40.7 kB]
# Get:298 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglu1-mesa amd64 9.0.0-2.1build1 [168 kB]
# Get:299 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-common-dev amd64 18.0.5-0ubuntu0~18.04.1 [536 kB]
# Get:300 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dev amd64 18.0.5-0ubuntu0~18.04.1 [4,444 B]
# Get:301 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglu1-mesa-dev amd64 9.0.0-2.1build1 [206 kB]
# Get:302 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu4 [145 kB]
# Get:303 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice-dev amd64 2:1.0.9-2 [46.8 kB]
# ...
# Regenerating fonts cache... done.
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up libwrap0:amd64 (7.6.q-27) ...
# Setting up libboost-math1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-regex1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-signals-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libwebp6:amd64 (0.6.1-2) ...
# Setting up libboost-locale1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libjsoncpp1:amd64 (1.7.4-3) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4.2) ...
# Setting up libboost-locale-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-tools-dev (1.65.1.0ubuntu1) ...
# Setting up libcairo2:amd64 (1.15.10-2) ...
# Setting up libasound2-dev:amd64 (1.1.3-5ubuntu0.1) ...
# Setting up libboost-program-options1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up libxcb-randr0-dev:amd64 (1.13-1) ...
# Setting up libsm-dev:amd64 (2:1.2.2-1) ...
# Setting up libboost-stacktrace1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu4) ...
# Setting up swig (3.0.12-1) ...
# Setting up libboost-atomic1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxkbcommon-dev (0.8.0-1ubuntu0.1) ...
# Setting up libavutil55:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libpciaccess-dev:amd64 (0.14-1) ...
# Setting up libltdl-dev:amd64 (2.4.6-2) ...
# Setting up libboost-atomic-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-test1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libopenmpt0:amd64 (0.3.6-1) ...
# Setting up libarchive13:amd64 (3.2.2-3.1ubuntu0.1) ...
# Setting up libboost-numpy1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libxpm-dev:amd64 (1:3.5.12-1) ...
# Setting up libflite1:amd64 (2.1-release-1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libboost-filesystem1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-stacktrace-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up mesa-vdpau-drivers:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libdmx-dev:amd64 (1:1.1.3-1) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libass9:amd64 (1:0.14.0-1) ...
# Setting up libxdamage-dev:amd64 (1:1.1.4-3) ...
# Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-2) ...
# Setting up libxres-dev (2:1.2.0-2) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up libcdio-cdda2:amd64 (10.2+0.94+2-2build1) ...
# Setting up libnl-route-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libboost-type-erasure1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up libboost-serialization1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libthai0:amd64 (0.1.27-2) ...
# Setting up libboost-chrono1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-graph1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxmuu-dev:amd64 (2:1.1.2-2) ...
# Setting up file (1:5.32-2ubuntu0.1) ...
# Setting up libboost-exception1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libswresample2:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libxss-dev:amd64 (1:1.2.2-1) ...
# Setting up libhwloc5:amd64 (1.11.9-1) ...
# Setting up libboost-log1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxmu6:amd64 (2:1.1.2-2) ...
# Setting up libboost-coroutine1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libhwloc-plugins (1.11.9-1) ...
# Setting up libdrm-intel1:amd64 (2.4.91-2) ...
# Setting up libfontenc-dev:amd64 (1:1.1.3-1) ...
# Setting up libboost-exception-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-random1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu4) ...
# Setting up librubberband2:amd64 (1.8.1-7ubuntu2) ...
# Setting up libboost-python1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libswscale4:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libboost-wave1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libwebpmux3:amd64 (0.6.1-2) ...
# Setting up mesa-va-drivers:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-context1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libpango-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libcdio-paranoia2:amd64 (10.2+0.94+2-2build1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up libxcb-shape0-dev:amd64 (1.13-1) ...
# Setting up libpostproc54:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.12~dfsg-2) ...
# Setting up libboost-timer1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libfs-dev:amd64 (2:1.0.7-1) ...
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-context-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libopenal1:amd64 (1:1.18.2-2) ...
# Setting up libboost-test-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-system1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-regex1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxi-dev:amd64 (2:1.7.9-1) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4.2) ...
# Setting up libboost-container1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libcaca0:amd64 (0.99.beta19-2build2~gcc5.3) ...
# Setting up libwayland-dev:amd64 (1.14.0-2) ...
# Setting up libboost-math1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up cmake (3.10.2-1ubuntu2) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libboost-math-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-numpy-dev (1.65.1.0ubuntu1) ...
# Setting up xfonts-base (1:1.0.4+nmu1) ...
# Setting up libboost-type-erasure1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-program-options-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-python-dev (1.65.1.0ubuntu1) ...
# Setting up vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up libxaw7:amd64 (2:1.0.13-1) ...
# Setting up libibverbs1:amd64 (17.1-1) ...
# Setting up libboost-fiber1.65.1:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-serialization-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxt-dev:amd64 (1:1.1.5-1) ...
# Setting up libboost-fiber1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-coroutine1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-graph1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libavresample3:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up x11-xkb-utils (7.7+3ubuntu0.18.04.1) ...
# Setting up libhwloc-dev:amd64 (1.11.9-1) ...
# Setting up libxmu-dev:amd64 (2:1.1.2-2) ...
# Setting up libboost-date-time1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libxcb-xfixes0-dev:amd64 (1.13-1) ...
# Setting up libboost-chrono-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxaw7-dev:amd64 (2:1.0.13-1) ...
# Setting up libboost-system-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-graph-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libdrm-dev:amd64 (2.4.91-2) ...
# Setting up libgl1-mesa-dri:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-type-erasure-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxvmc-dev:amd64 (2:1.0.10-1) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-fiber-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up librdmacm1:amd64 (17.1-1) ...
# Setting up libboost-iostreams1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-date-time-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-filesystem1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libpangoft2-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libboost-container-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxtst-dev:amd64 (2:1.2.3-1) ...
# Setting up libxfont-dev (1:2.0.3-1) ...
# Setting up libsndfile1:amd64 (1.0.28-4) ...
# Setting up i965-va-driver:amd64 (2.1.0-0ubuntu1) ...
# Setting up libboost-random-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libboost-thread1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-timer1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-iostreams-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up va-driver-all:amd64 (2.1.0-3) ...
# Setting up ibverbs-providers:amd64 (17.1-1) ...
# Setting up libboost-regex-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libxcb-present-dev:amd64 (1.13-1) ...
# Setting up libboost-coroutine-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libibverbs-dev:amd64 (17.1-1) ...
# Setting up libglx-mesa0:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.2) ...
# Setting up mesa-common-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-thread-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libfabric1 (1.5.3-1) ...
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libboost-wave1.65-dev:amd64 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-timer-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libboost-filesystem-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libpulse0:amd64 (1:11.1-1ubuntu7.1) ...
# Setting up libboost-log1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.1) ...
# Setting up libboost-wave-dev:amd64 (1.65.1.0ubuntu1) ...
# Setting up libopenmpi2:amd64 (2.1.1-8) ...
# Setting up libglx0:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up mir-client-platform-mesa-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.1) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.1) ...
# Setting up librsvg2-2:amd64 (2.40.20-2) ...
# Setting up libboost-mpi1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libopenmpi-dev (2.1.1-8) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/openmpi/include to provide /usr/include/mpi (mpi) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpicc.1.gz because associated file /usr/share/man/man1/mpicc.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpic++.1.gz because associated file /usr/share/man/man1/mpic++.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpicxx.1.gz because associated file /usr/share/man/man1/mpicxx.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiCC.1.gz because associated file /usr/share/man/man1/mpiCC.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpif77.1.gz because associated file /usr/share/man/man1/mpif77.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpif90.1.gz because associated file /usr/share/man/man1/mpif90.openmpi.1.gz (of link group mpi) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpifort.1.gz because associated file /usr/share/man/man1/mpifort.openmpi.1.gz (of link group mpi) doesn't exist
# Setting up libavcodec57:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up openmpi-bin (2.1.1-8) ...
# update-alternatives: using /usr/bin/mpirun.openmpi to provide /usr/bin/mpirun (mpirun) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpirun.1.gz because associated file /usr/share/man/man1/mpirun.openmpi.1.gz (of link group mpirun) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiexec.1.gz because associated file /usr/share/man/man1/mpiexec.openmpi.1.gz (of link group mpirun) doesn't exist
# Setting up librsvg2-common:amd64 (2.40.20-2) ...
# Setting up mpi-default-dev (1.10) ...
# Setting up libboost-log-dev (1.65.1.0ubuntu1) ...
# Setting up libgl1:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up libglu1-mesa:amd64 (9.0.0-2.1build1) ...
# Setting up xserver-xorg-dev (2:1.19.6-1ubuntu4.2) ...
# Setting up libboost-mpi1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up mpi-default-bin (1.10) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up xorg-dev (1:7.7+19ubuntu7.1) ...
# Setting up libchromaprint1:amd64 (1.4.3-1) ...
# Setting up libboost-graph-parallel1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.2) ...
# Setting up libboost-graph-parallel1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libglvnd-dev:amd64 (1.0.0-2ubuntu2.2) ...
# Setting up libgl1-mesa-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libegl1-mesa-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-graph-parallel-dev (1.65.1.0ubuntu1) ...
# Setting up libboost-mpi-dev (1.65.1.0ubuntu1) ...
# Setting up libavformat57:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libboost-mpi-python1.65.1 (1.65.1+dfsg-0ubuntu5) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.0-2.1build1) ...
# Setting up libavfilter6:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up libgles2-mesa-dev:amd64 (18.0.5-0ubuntu0~18.04.1) ...
# Setting up libboost-mpi-python1.65-dev (1.65.1+dfsg-0ubuntu5) ...
# Setting up libboost-mpi-python-dev (1.65.1.0ubuntu1) ...
# Setting up libboost-all-dev (1.65.1.0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.1) ...
# Setting up libavdevice57:amd64 (7:3.4.4-0ubuntu0.18.04.1) ...
# Setting up ffmpeg (7:3.4.4-0ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Collecting gym
#   Downloading https://files.pythonhosted.org/packages/d4/22/4ff09745ade385ffe707fb5f053548f0f6a6e7d5e98a2b9d6c07f5b931a7/gym-0.10.9.tar.gz (1.5MB)
#     100% |████████████████████████████████| 1.5MB 15.4MB/s
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/39/37/f285403a09cc261c56b6574baace1bdcf4b8c7428c8a7239cbba137bc0eb/PyVirtualDisplay-0.2.1.tar.gz
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.14.6)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.11.0)
# Collecting pyglet>=1.2.0 (from gym)
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
#     100% |████████████████████████████████| 1.0MB 20.0MB/s
# Collecting EasyProcess (from pyvirtualdisplay)
#   Downloading https://files.pythonhosted.org/packages/0d/f1/d2de7591e7dfc164d286fa16f051e6c0cf3141825586c3b04ae7cda7ac0f/EasyProcess-0.2.3.tar.gz
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2018.10.15)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym) (0.16.0)
# Building wheels for collected packages: gym, pyvirtualdisplay, EasyProcess
# done
#   Stored in directory: /root/.cache/pip/wheels/6c/3a/0e/b86dee98876bb56cdb482cc1f72201035e46d1baf69d10d028
# done
#   Stored in directory: /root/.cache/pip/wheels/d1/8c/16/1c64227974ae29c687e4cc30fd691d5c0fd40f54446dde99da
# done
#   Stored in directory: /root/.cache/pip/wheels/b4/c6/e3/c163b04029d8fccfd54b809802640c1af587a01be8d7a04e1a
# Successfully built gym pyvirtualdisplay EasyProcess
# Installing collected packages: pyglet, gym, EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.2.3 gym-0.10.9 pyglet-1.3.2 pyvirtualdisplay-0.2.1

# %% [markdown]
# ## Torch + torchvision installation (Py3.6)

# %%
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
# Out:
# Collecting torch==0.4.1 from http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
#   Downloading http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl (483.0MB)
#     100% |████████████████████████████████| 483.0MB 51.6MB/s
# tcmalloc: large alloc 1073750016 bytes == 0x568fc000 @  0x7fdd249222a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# Installing collected packages: torch
# Successfully installed torch-0.4.1
# Collecting torchvision
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 5.2MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Collecting pillow>=4.1.1 (from torchvision)
#   Downloading https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 8.0MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision) (0.4.1)
# Installing collected packages: pillow, torchvision
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# Successfully installed pillow-5.3.0 torchvision-0.2.1

# %%
import torch # Check if everything is OK

# %% [markdown]
# ## Setting up the environment

# %%
import gym
import math
import random
import numpy as np

# Some stuff that we will need to visualize the simulations in the notebook
import matplotlib.pyplot as plt
import matplotlib.animation
from IPython.display import HTML

# Start virtual display
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torch.autograd import Variable
import torch.nn.utils as utils

env = gym.make('CartPole-v0').unwrapped

print("Action space (discrete): {}".format( env.action_space.n))
print("Observation space (discrete): {}".format( env.observation_space))

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Action space (discrete): 2
# Observation space (discrete): Box(4,)
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# ## Create the model
#
# We will keep the same network use on lab 6 but we are gonna add a replay memory to the agent:

# %%
 
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)
      
class DQN(nn.Module):

    def __init__(self):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)
        self.head = nn.Linear(448, 2)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %% [markdown]
# ### Image processing

# %%
resize = T.Compose([T.ToPILImage(),
                    T.Resize(40, interpolation=Image.CUBIC),
                    T.ToTensor()])

# This is based on the code from gym.
screen_width = 600

print(env)
def get_cart_location():
    world_width = env.x_threshold * 2
    scale = screen_width / world_width
    return int(env.state[0] * scale + screen_width / 2.0)  # MIDDLE OF CART


def get_screen():
    screen = env.render(mode='rgb_array').transpose(
        (2, 0, 1))  # transpose into torch order (CHW)
    # Strip off the top and bottom of the screen
    screen = screen[:, 160:320]
    view_width = 320
    cart_location = get_cart_location()
    if cart_location < view_width // 2:
        slice_range = slice(view_width)
    elif cart_location > (screen_width - view_width // 2):
        slice_range = slice(-view_width, None)
    else:
        slice_range = slice(cart_location - view_width // 2,
                            cart_location + view_width // 2)
    # Strip off the edges, so that we have a square image centered on a cart
    screen = screen[:, :, slice_range]
    # Convert to float, rescare, convert to torch tensor
    # (this doesn't require a copy)
    screen = np.ascontiguousarray(screen, dtype=np.float32) / 255
    screen = torch.from_numpy(screen)
    # Resize, and add a batch dimension (BCHW)
    return resize(screen).unsqueeze(0).to(device)


env.reset()
plt.figure()
plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
           interpolation='none')
plt.title('Example extracted screen')
# Out:
# <CartPoleEnv<CartPole-v0>>
# Text(0.5,1,'Example extracted screen')

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

policy_net = DQN().to(device)
target_net = DQN().to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.RMSprop(policy_net.parameters())
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(2)]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations():
    #plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated

# %% [markdown]
# ### Training loop!!

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see http://stackoverflow.com/a/19343/3343043 for
    # detailed explanation).
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.uint8)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 3500
for i_episode in range(num_episodes):
    # Initialize the environment and state
    env.reset()
    last_screen = get_screen()
    current_screen = get_screen()
    state = current_screen - last_screen
    for t in count():
        # Select and perform an action
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)

        # Observe new state
        last_screen = current_screen
        current_screen = get_screen()
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the target network)
        optimize_model()
        if done:
            episode_durations.append(t + 1)
            plot_durations()
            break
    # Update the target network
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
env.close()
plt.ioff()
